# %% [markdown]
# <a href="https://colab.research.google.com/github/Wiz22ard/webScraping/blob/main/BANPT/script/Scrape_BANPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrape Data BAN PT

# %% [markdown]
# url : <https://www.banpt.or.id/>

# %% [markdown]
# ## Scrape Data Akreditasi Program Studi

# %%
import requests
import pandas as pd

cookies = {
    '_ga': 'GA1.1.375618888.1744597228',
    'PHPSESSID': '89vg7i9cp59vsktp4g4qp93gj5',
    '_ga_BQZVL0B4JE': 'GS1.1.1744597227.1.1.1744597366.0.0.0',
    'sc_is_visitor_unique': 'rx12333374.1744597367.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'en-US,en;q=0.9,id;q=0.8',
    'priority': 'u=1, i',
    'referer': 'https://www.banpt.or.id/direktori/prodi/pencarian_prodi.php',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': '_ga=GA1.1.375618888.1744597228; PHPSESSID=89vg7i9cp59vsktp4g4qp93gj5; _ga_BQZVL0B4JE=GS1.1.1744597227.1.1.1744597366.0.0.0; sc_is_visitor_unique=rx12333374.1744597367.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

params = {
    '_': '1744597366593',
}

mayor_resp = requests.get(
    'https://www.banpt.or.id/direktori/model/dir_prodi/get_hasil_pencariannew.php',
    params=params,
    cookies=cookies,
    headers=headers,
)
mayor_data = mayor_resp.json()

mayor_rows=[]
i = 1
for univ in mayor_data['data']:
    mayor_rows.append({
        'No':i,
        'Perguruan Tinggi':univ[0],
        'Program Studi':univ[1],
        'Strata':univ[2],
        'Wilayah':univ[3],
        'No. SK':univ[4],
        'Tahun SK':univ[5],
        'Peringkat':univ[6],
        'Tanggal Kadaluarsa':univ[7],
        'Status Kadaluarsa':univ[8]
    })
    i += 1

mayor_df = pd.DataFrame(mayor_rows)
mayor_df.sort_values(by=['Perguruan Tinggi', 'Program Studi'], inplace=True)
mayor_df.reset_index(drop=True, inplace=True)
mayor_df.to_csv('banpt_program_studi.csv', index=False, encoding='utf-8-sig')
mayor_df
# Out:
#           No                                   Perguruan Tinggi  \
# 0      15686                001020 - 001020 - Universitas Jambi
# 1      15873                  002003 - Institut Pertanian Bogor
# 2      15674  AKADEMI ADMINISTRASI RUMAH SAKIT MATARAM, MATARAM
# 3       4142              AKADEMI AKUPUNKTUR SURABAYA, SURABAYA
# 4       8817  AKADEMI ANALIS FARMASI &amp; PUTERA INDONESIA,...
# ...      ...                                                ...
# 33412  20103                    Universitas Yuppentek Indonesia
# 33413  11464                    Universitas Yuppentek Indonesia
# 33414  11466                    Universitas Yuppentek Indonesia
# 33415  11465                    Universitas Yuppentek Indonesia
# 33416  11346                         Unversitas Mitra Indonesia
#
#                     Program Studi Strata Wilayah  \
# 0                           Kimia     S1     PTN
# 1                      Matematika     S1     PTN
# ...

# %% [markdown]
# ## Scrape Data Akreditasi Institusi

# %%
import requests
import pandas as pd

cookies = {
    '_ga': 'GA1.1.375618888.1744597228',
    'PHPSESSID': '89vg7i9cp59vsktp4g4qp93gj5',
    '_ga_BQZVL0B4JE': 'GS1.1.1744597227.1.1.1744598599.0.0.0',
    'sc_is_visitor_unique': 'rx12333374.1744598600.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'en-US,en;q=0.9,id;q=0.8',
    'priority': 'u=1, i',
    'referer': 'https://www.banpt.or.id/direktori/institusi/pencarian_institusi.php',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': '_ga=GA1.1.375618888.1744597228; PHPSESSID=89vg7i9cp59vsktp4g4qp93gj5; _ga_BQZVL0B4JE=GS1.1.1744597227.1.1.1744598599.0.0.0; sc_is_visitor_unique=rx12333374.1744598600.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

params = {
    '_': '1744598599448',
}

institution_resp = requests.get(
    'https://www.banpt.or.id/direktori/model/dir_aipt/get_data_institusi.php',
    params=params,
    cookies=cookies,
    headers=headers,
)
institution_data = institution_resp.json()

institution_rows=[]
i = 1
for institution in institution_data['data']:
    institution_rows.append({
        'No':i,
        'Perguruan Tinggi':institution[0],
        'Peringkat':institution[1],
        'No. SK':institution[2],
        'Tahun SK':institution[3],
        'Wilayah':institution[4],
        'Tanggal Kadaluarsa':institution[5],
        'Status Kadaluarsa':institution[6]
    })
    i += 1

institution_df = pd.DataFrame(institution_rows)
institution_df.sort_values(by=['Perguruan Tinggi'], inplace=True)
institution_df.reset_index(drop=True, inplace=True)
institution_df.to_csv('banpt_institusi.csv', index=False, encoding='utf-8-sig')
institution_df
# Out:
#         No                                   Perguruan Tinggi  \
# 0     2463                        AKPER Mappa Oudang Makassar
# 1     1450                   AKPER Putra Pertiwi Watansoppeng
# 2     3794  AKTEK Radiodiagnostik &amp; Terapi Citra Intan...
# 3     1648         AKTEK Radiodiagnostik Dan Radioterapi Bali
# 4     2420                                   AMIK Bukittinggi
# ...    ...                                                ...
# 4086  2944                            Universitas Yos Sudarso
# 4087  3074                      Universitas Yudharta Pasuruan
# 4088  1415                    Universitas Yuppentek Indonesia
# 4089  1286                           Universitas dr. Soebandi
# 4090   432  sekolah Tinggi Keguruan dan Ilmu Pendidikan Ro...
#
#                 Peringkat                             No. SK Tahun SK Wilayah  \
# 0                    Baik   1944/SK/BAN-PT/Ak.Ppj/PT/XI/2022     2022      09
# ...

# %% [markdown]
# ## Scrape Usulan Program Studi Baru

# %%
import requests
import pandas as pd

cookies = {
    '_ga': 'GA1.1.375618888.1744597228',
    'sc_is_visitor_unique': 'rx12333374.1744598600.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
    '_ga_BQZVL0B4JE': 'GS1.1.1744597227.1.1.1744599057.0.0.0',
    'sc_is_visitor_unique': 'rx12333374.1744599058.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'en-US,en;q=0.9,id;q=0.8',
    'priority': 'u=1, i',
    'referer': 'https://service.banpt.or.id/direktori/prodi/pencarian_prodi_baru.php',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': '_ga=GA1.1.375618888.1744597228; sc_is_visitor_unique=rx12333374.1744598600.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1; _ga_BQZVL0B4JE=GS1.1.1744597227.1.1.1744599057.0.0.0; sc_is_visitor_unique=rx12333374.1744599058.512A9DAE57BF472588AD4B1D7BD2FFF7.1.1.1.1.1.1.1.1.1',
}

params = {
    '_': '1744599057635',
}

new_mayor_resp = requests.get(
    'https://service.banpt.or.id/direktori/model/dir_prodi/prodi_baru.php',
    params=params,
    cookies=cookies,
    headers=headers,
)

new_mayor_data = new_mayor_resp.json()

new_mayor_rows=[]
i = 1
for new_mayor in new_mayor_data['data']:
    new_mayor_rows.append({
        'No':i,
        'Perguruan Tinggi':new_mayor[0],
        'Program Studi':new_mayor[1],
        'Program':new_mayor[2],
        'Tanggal Terima':new_mayor[3],
        'Status':new_mayor[4]
    })
    i += 1

new_mayor_df = pd.DataFrame(new_mayor_rows)
new_mayor_df.sort_values(by=['Tanggal Terima'], ascending=False, inplace=True)
new_mayor_df.reset_index(drop=True, inplace=True)
new_mayor_df.to_csv('banpt_program_studi_baru.csv', index=False, encoding='utf-8-sig')
new_mayor_df
# Out:
#         No                                   Perguruan Tinggi  \
# 0     4321            Sekolah Tinggi Agama Islam Persis Garut
# 1     4320            Sekolah Tinggi Agama Islam Persis Garut
# 2     4319              Institut Agama Islam Negeri Pontianak
# 3     4318    Universitas Islam Negeri K.H. Abdurrahman Wahid
# 4     4317                Universitas Nurul Jadid Probolinggo
# ...    ...                                                ...
# 4317  1444                   Universitas Pendidikan Indonesia
# 4318  1457                              Universitas Indonesia
# 4319  1458                         Universitas Sumatera Utara
# 4320  1982  Universitas Katolik Indonesia Santu Paulus Ruteng
# 4321  2001         Universitas Muhammadiyah Sidenreng Rappang
#
#                            Program Studi Program Tanggal Terima  \
# 0      B-152/DJ.I/Dt.I.III/PP.01/03/2025      S1     2025-03-14
# 1                            Ilmu Hadits      S2     2025-03-14
# ...
